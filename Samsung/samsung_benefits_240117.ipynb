# %%
# %pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Using cached webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging in c:\users\유지민\appdata\roaming\python\python38\site-packages (from webdriver_manager) (23.2)
# Requirement already satisfied: requests in c:\users\유지민\appdata\local\programs\python\python38\lib\site-packages (from webdriver_manager) (2.28.1)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\유지민\appdata\local\programs\python\python38\lib\site-packages (from requests->webdriver_manager) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\유지민\appdata\local\programs\python\python38\lib\site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\유지민\appdata\local\programs\python\python38\lib\site-packages (from requests->webdriver_manager) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\유지민\appdata\local\programs\python\python38\lib\site-packages (from requests->webdriver_manager) (2022.9.24)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.0.0 webdriver-manager-4.0.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\유지민\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'c:\Users\유지민\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import re

# %%
# 카드 혜택 요약 정보 크롤링 함수
def crawl_card_summary(driver, card_url):
    driver.get(card_url)
    driver.implicitly_wait(10)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 카드 요약 정보 딕셔너리
    card_summary = {
        "Card Summary": []
    }

    # 카드 요약 크롤링 코드
    ul_dot_elements = soup.find_all('ul', {'class': 'txt-list-dot'})
    if ul_dot_elements:
        for ul_dot_element in ul_dot_elements:
            for text in ul_dot_element.stripped_strings:
                card_summary['Card Summary'].append(text)

    return card_summary

# %%
# 카드 혜택 상세 정보 크롤링 함수
def crawl_card_benefit(driver, card_url):
    driver.get(card_url)
    driver.implicitly_wait(10)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 카드 상세 정보 딕셔너리
    card_info = {
        "Card Benefit": []
    }

    # 카드 혜택 크롤링 코드
    container_box = soup.find('section', class_='tab-container')
    div_boxes = container_box.find_all('div', class_='list_box_nt')
    for div_box in div_boxes:
        titles = div_box.find_all('h5', class_='tit04') # 타이틀 리스트
        tables = div_box.find_all('div', class_='table_col') # 표 리스트
        uls = div_box.find_all('ul', class_='txt_list') # ul 리스트
        service_infos = uls[0].find_all('span', class_='txt_bar')
        if service_infos[0] and (service_infos[0].text.strip()[-2:] == "할인" or service_infos[0].text.strip()[-3:] == "할인)" 
                                 or service_infos[0].text.strip()[-8:-6] == "할인" or service_infos[0].text.strip()[-2:] == "적립" 
                                 or service_infos[0].text.strip()[-11:-9] == "할인" or service_infos[0].text.strip()[-14:-12] == "할인" 
                                 or service_infos[0].text.strip()[-2:] == "무료") or service_infos[0].text.strip()[-12:-10] == "할인":
            num = 0 # 타이틀 번호
            table_num = 0 # 표 번호
            uls_num = 1
            # 서비스 안내
            if titles[num].text == "서비스안내":
                title1 = titles[num].text
                num = num+1
                card_info['Card Benefit'].append(str(num) + ") " + title1)
                card_info['Card Benefit'].append(uls[0].text.replace('\n', ''))
                next_ul_check = uls[uls_num]
                if next_ul_check.text.strip().startswith("자세한 내용"):
                    uls_num += 1
            
            # 대상점
            if titles[num].text == "대상점":
                title2 = titles[num].text
                num = num+1
                table1 = tables[table_num]
                table_num = table_num+1

                target_title = table1.find('thead')
                target_shops = table1.find('tbody')
                card_info['Card Benefit'].append(str(num) + ") " + title2)
                if target_title:
                    card_info['Card Benefit'].append(target_title.text.replace('\n', ''))
                card_info['Card Benefit'].append(target_shops.text.replace('\n', ''))

            # 연간 이용금액대별 적립률
            if titles[num].text == "연간 이용금액대별 적립률":
                title2 = titles[num].text
                num = num+1
                card_info['Card Benefit'].append(str(num) + ") " + title2)
                table2 = tables[table_num]
                table_num = table_num+1                   
                table_title = table2.find('caption').text # 테이블 이름
                card_info['Card Benefit'].append(table_title)
                # 테이블 요소 개수 count
                table_tr = table2.find_all('tr')
                table2_tr_num = len(table_tr)
                # 구분 list
                table2_discount_prices = table_tr[0].find_all('th')
                # 기본 적립 list
                table2_tbody = table2.find('tbody')
                table2_tbody_tr = table2_tbody.find_all('tr')
                table2_basic_points = table2_tbody_tr[0].find_all('td')
                # 추가 적립 list
                table2_plus_points = table2_tbody_tr[1].find_all('td')
                for i in range(min(len(table2_discount_prices), len(table2_basic_points), len(table2_plus_points))):
                    table2_price = table2_discount_prices[i].text
                    table2_basic_point = table2_basic_points[i].text
                    table2_plus_point = table2_plus_points[i].text
                    card_info['Card Benefit'].append(f"{table2_price} 기본 적립:{table2_basic_point} 추가 적립:{table2_plus_point}")
            

            # 이용한도 및 조건
            if titles[num].text == "이용한도 및 조건":
                title2 = titles[num].text
                num = num+1
                card_info['Card Benefit'].append(str(num) + ") " + title2)
                max_and_conditions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                for max_and_condition in max_and_conditions:
                    card_info['Card Benefit'].append(max_and_condition.text.replace('\n', '')) 


            # 할인기준
            if titles[num].text == "할인기준":
                title3 = titles[num].text
                num = num+1
                table2 = tables[table_num]
                table_num = table_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title3)
                table_title = table2.find('caption').text # 테이블 이름
                card_info['Card Benefit'].append(table_title)
                # 테이블 요소 개수 count
                table_tr = table2.find_all('tr')
                table2_tr_num = len(table_tr)
                # 할인 기준 금액 list
                table2_discount_prices = table_tr[1].find_all('th')
                # 할인한도 금액 list
                table2_tbody = table2.find('tbody')
                table2_contents = table2_tbody.find_all('tr')

                for table2_discount_price in table2_discount_prices:
                    card_info['Card Benefit'].append(table2_discount_price.text)

                for table2_content in table2_contents:
                    card_info['Card Benefit'].append(table2_content.text)

            # 전월 이용금액대별 통합 월 할인한도
            if titles[num].text == "전월 이용금액대별 통합 월 할인한도":
                title3 = titles[num].text
                num = num+1
                table2 = tables[table_num]
                table_num = table_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title3)
                table_title = table2.find('caption').text # 테이블 이름
                card_info['Card Benefit'].append(table_title)
                # 테이블 요소 개수 count
                table_tr = table2.find_all('tr')
                table2_tr_num = len(table_tr)
                # 할인 기준 금액 list
                table2_discount_prices = table_tr[0].find_all('th')
                # 할인한도 금액 list
                table2_tbody = table2.find('tbody')
                table2_contents = table2_tbody.find_all('td')

                for i in range(min(len(table2_discount_prices), len(table2_contents))):
                    table2_price = table2_discount_prices[i].text
                    table2_content = table2_contents[i].text
                    card_info['Card Benefit'].append(table2_price + " " + table2_content)

            # 전월 이용금액대별 할인율 및 통합 월 할인한도
            if titles[num].text == "전월 이용금액대별 할인율 및 통합 월 할인한도":
                title4 = titles[num].text
                num = num+1
                table3 = tables[table_num]
                table_num = table_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title4)
                table_title = table3.find('caption').text # 테이블 이름     
                card_info['Card Benefit'].append(table_title)
                table_element1 = table3.find('thead')
                table_use_prices = table_element1.find_all('th', scope='col') # 전월 이용금액 리스트
                table3_num = len(table_use_prices) # 테이블 요소 개수
                table_element2 = table3.find('tbody')
                table_discount_contents = table_element2.find_all('tr')
                table_discount_percents = table_discount_contents[0] # 할인율 리스트
                table_discount_maxs = table_discount_contents[1] # 할인 한도 리스트
                table_discount_percents_detail = table_discount_percents.find_all('span', class_='ls0') # 할인율 리스트
                table_discount_maxs_detail = table_discount_maxs.find_all('td', class_='al_r')
                for i in range(table3_num-1):
                    table_price = table_use_prices[i+1].text
                    table_discount_percent = table_discount_percents_detail[i].text
                    table_discount_max = table_discount_maxs_detail[i].text
                    card_info['Card Benefit'].append(table_price + " 할인율:" + table_discount_percent + " 할인 한도:" + table_discount_max)

            # 이용방법
            if num < len(titles) and titles[num].text == "이용방법":
                title5 = titles[num].text
                num = num+1
                exceptions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title5)
                for exception in exceptions:
                    card_info['Card Benefit'].append(exception.text.replace('\n', ''))

            # 적립기준
            if titles[num].text == "적립기준":
                title2 = titles[num].text
                num = num+1
                table1 = tables[table_num]
                table_num = table_num+1

                target_title = table1.find('thead')
                target_shops = table1.find('tbody')
                card_info['Card Benefit'].append(str(num) + ") " + title2)
                if target_title:
                    card_info['Card Benefit'].append(target_title.text.replace('\n', ''))
                card_info['Card Benefit'].append(target_shops.text.replace('\n', ''))

            # 이용조건
            if (titles[num].text == "이용조건") or (titles[num].text == "이용 조건 "):
                title4 = titles[num].text
                num = num+1
                condition_infos = uls[uls_num].find_all('li')
                condition_uls = uls[uls_num].find_all('ul', class_='txt_list')
                if condition_uls:
                    uls_num = uls_num + 1
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title4)
                for condition_info in condition_infos:
                    card_info['Card Benefit'].append(condition_info.text.replace('\n', ''))

            # 적립 제외 대상
            if titles[num].text == "적립 제외 대상":
                title5 = titles[num].text
                num = num+1
                exceptions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title5)
                for exception in exceptions:
                    card_info['Card Benefit'].append(exception.text.replace('\n', ''))
                
            # 할인 제외 대상
            if num < len(titles) and titles[num].text == "할인 제외 대상":
                title5 = titles[num].text
                num = num+1
                exceptions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title5)
                for exception in exceptions:
                    card_info['Card Benefit'].append(exception.text.replace('\n', ''))

            # 부가세환급 편의지원서비스
            if num < len(titles) and titles[num].text == "부가세환급 편의지원서비스":
                title5 = titles[num].text
                num = num+1
                exceptions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title5)
                for exception in exceptions:
                    card_info['Card Benefit'].append(exception.text.replace('\n', ''))

            # 전월 이용금액 기준
            if num < len(titles) and titles[num].text == "전월 이용금액 기준":
                title5 = titles[num].text
                num = num+1
                exceptions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title5)
                for exception in exceptions:
                    card_info['Card Benefit'].append(exception.text.replace('\n', ''))

            # 기타
            if num < len(titles) and titles[num].text == "기타":
                title5 = titles[num].text
                num = num+1
                exceptions = uls[uls_num].find_all('li')
                uls_num = uls_num+1
                card_info['Card Benefit'].append(str(num) + ") " + title5)
                for exception in exceptions:
                    card_info['Card Benefit'].append(exception.text.replace('\n', ''))

    return card_info

# %%
# 크롤링 정보 정리 (특수문자 제거 및 줄바꿈 제거)
def remove_special_characters(text):

    # 특수문자 제거
    text_str = str(text)
    cleaned_text = re.sub(r'[^\w가-힣\s.%~]', '', text_str)

    # 여러 개의 공백을 하나의 공백으로 변환
    cleaned_text = ' '.join(cleaned_text.split())

    return cleaned_text

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# 카드 리스트 페이지 URL
card_list_url = "https://www.samsungcard.com/home/card/cardinfo/PGHPPDCCardCardinfoRecommendPC001"
driver.get(card_list_url)
driver.implicitly_wait(10)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# 카드 리스트 및 혜택 정보 담는 객체
card_list = []

# 카드 리스트 링크 가져오기
card_lists = soup.find_all('ul', class_='lists')
card_list = card_lists[1]
card_elements = card_list.find_all('li')

for card_element in card_elements:

    # 카드 이름 정보
    card_name = card_element.find('div', class_='tit-h4')
    print(card_name.text)

    # 카드 이미지 정보
    card_img = card_element.find('img')
    card_img_url = card_img.get('src')
    print(card_img_url)

    # 카드 고유 번호 추출
    card_url_code = card_img_url[-11:-4]
    card_url = f"https://www.samsungcard.com/home/card/cardinfo/PGHPPCCCardCardinfoDetails001?code={card_url_code}"

    # 카드 혜택 요약 정보
    card_summay_benefit = crawl_card_summary(driver, card_url)
    clean_card_summary_benefit = remove_special_characters(card_summay_benefit)
    print(clean_card_summary_benefit)

    # 카드 혜택 상세 정보
    card_detail_benefit = crawl_card_benefit(driver, card_url)
    clean_card_detail_benefit = remove_special_characters(card_detail_benefit)
    print(clean_card_detail_benefit)

driver.quit()
# Out:
# 삼성 iD ON 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/IDON_AAP1731.gif
# Card Summary
# Card Benefit 1 서비스안내 커피전문점배달앱델리 영역 중 월 이용금액이 가장 큰 1개 영역에 대해 30% 결제일할인온라인 간편결제해외 3%1% 할인 혜택과 중복 적용 2 대상점 영역 할인 대상 커피전문점스타벅스 이디야커피 커피빈 투썸플레이스 블루보틀배달앱배달의민족 요기요델리쉐이크쉑 써브웨이 파리바게뜨 배스킨라빈스 던킨 3 이용조건 월 할인한도 10000원 전월 이용금액 30만원 이상 시 제공 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 교통이동통신스트리밍 10% 결제일할인 2 대상점 업종 할인 대상 교통대중교통버스 지하철 택시이동통신SKT KT LG U 알뜰폰 이동통신요금 정기결제건스트리밍넷플릭스 웨이브 티빙 왓챠 멜론 FLO 정기결제건 3 할인기준 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 30만원 이상 60만원 이상 n10000원n20000원n 4 이용조건 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 30만원 이상~60만원 미만 실적구간 혜택 제공전월 이용금액 60만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 교통이동통신스트리밍 10% 할인이 적용되지 않은 대중교통 및 택시 이용금액 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 온라인 간편결제해외 3% 결제일할인전월 이용금액 30만원 미만 시 또는 월 할인한도 초과 시에는 1% 결제일할인 2 대상점 업종할인 대상 온라인 간편결제삼성페이 네이버페이 카카오페이 PAYCO 스마일페이 coupay SSGPAY L.PAY해외해외 가맹점 및 해외 직접구매 이용건 3 전월 이용금액대별 할인율 및 통합 월 할인한도 전월 이용금액대별 할인율 및 통합 월 할인한도를 확인할 수 있는 표입니다. 30만원 미만 할인율1% 할인 한도 30만원 이상 할인율3% 할인 한도5000원 60만원 이상 할인율3% 할인 한도10000원 4 이용조건 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 30만원 이상~60만원 미만 실적구간 혜택 제공전월 이용금액 60만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금 국세지방세공과금 초중고등학교 학교납입금 대학 등록금 교통이동통신스트리밍 10% 할인이 적용되지 않은 대중교통 및 택시 이용금액 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 부동산 임대료 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 문자알림서비스 스마트오토서비스 이용금액
# 삼성 iD VITA 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1790.gif
# Card Summary 의료 20% 결제일할인 보험 10% 결제일할인 헬스뷰티 20% 결제일할인 할인점 10% 결제일할인 이동통신렌탈멤버십 10% 결제일할인 해외 1% 결제일할인
# Card Benefit
# 삼성 iD SIMPLE 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1767.gif
# Card Summary 카드 디자인 소개 국내외 가맹점 0.7% 결제일할인 국내외 가맹점 1% 결제일할인 온라인쇼핑몰 멤버십 50% 결제일할인 영화 3천원 결제일할인
# Card Benefit 1 서비스안내 전월 이용금액에 관계없이 할인한도 없이 국내외 가맹점에서 건별 10만원 미만 결제 시 0.7% 결제일할인 2 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금 국세지방세 공과금 납부건 부동산 임대료 납부건 초중고등학교 학교납입금 대학 등록금 납부건 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 납부건 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 문자알림서비스 스마트오토서비스 이용금액 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 전월 이용금액에 관계없이 할인한도 없이 국내외 가맹점에서 건별 10만원 이상 결제 시 1% 결제일할인 2 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금 국세지방세 공과금 납부건 부동산 임대료 납부건 초중고등학교 학교납입금 대학 등록금 납부건 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 납부건 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 문자알림서비스 스마트오토서비스 이용금액 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 온라인쇼핑몰 멤버십 정기결제 시 50% 결제일할인 2 대상점 업종할인 대상 온라인쇼핑몰 멤버십쿠팡 로켓와우 멤버십 마켓컬리 컬리패스 네이버플러스 멤버십 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 30만원 이상 시 제공 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 영화 티켓 건별 10000원 이상 결제 시 3000원 결제일할인 2 대상점 업종할인 대상 영화CGV 롯데시네마 메가박스 3 이용조건 통합 월1회 제공 전월 이용금액 30만원 이상 시 제공 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건
# 삼성 iD ENERGY 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1753.gif
# Card Summary
# Card Benefit 1 서비스안내 주유 건별 10000원 이상 결제 시 10000원 결제일할인월 합산 30000원까지 할인 2 대상점 업종할인 대상 주유SK에너지 GS칼텍스 SOIL 현대오일뱅크 3 할인기준 전월 이용금액대별 통합 월 할인횟수를 확인할 수 있는 표입니다. 50만원 이상 100만원 이상 150만원 이상 n1회n2회n3회n 4 이용조건 통합 일 1회 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 50만원 이상~100만원 미만 실적구간 혜택 제공전월 이용금액 100만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 대중교통택시전기차 충전요금 10% 결제일할인 2 대상점 구분할인 대상 대중교통버스 지하철택시택시전기차 충전 사업자환경부한국자동차환경협회파워큐브 한국전력 테슬라 지에스차지비 한국전기차충전서비스xa0SKxa0일렉링크 대영채비 EPit 제주전기자동차서비스 소프트베리 SK에너지 GS칼텍스 에버온 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 주차장대리운전 10% 결제일할인 2 대상점 구분할인 대상 주차장케이엠파크대리운전카카오 T 대리 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 고속도로 통행료 10% 결제일할인 2 이용조건 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 3 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 스타벅스 드라이브 스루 매장에서 My DT Pass를 통해 결제 시 30% 결제일할인 2 대상점 구분할인 대상 스타벅스스타벅스 DT드라이브 스루 매장 3 이용조건 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 엔진오일오일필터에어클리너 포함 교환 시 20000원 현장할인연 2회차량 안전점검 무료연 1회타이어 펑크 수리 무료연 1회 1개 기준타이어 위치 교환 무료연 1회 휠밸런스 2개 포함 2 대상점 업종할인 대상 차량정비스피드메이트 3 이용조건 연 기준 1.1~12.31 전월 이용금액 50만원 이상 시 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건
# 삼성 iD PET 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/b_AAP1773.gif
# Card Summary 카드 디자인 소개 동물병원반려동물쇼핑몰 30% 결제일할인 온라인 간편결제 5% 결제일할인 손해보험 10% 결제일할인 해외 1.5% 결제일할인 스트리밍 10% 결제일할인 커피전문점편의점 1000원 결제일할인
# Card Benefit 1 서비스안내 동물병원반려동물쇼핑몰 30% 결제일할인 2 대상점 구분할인 대상 동물병원동물병원 업종반려동물쇼핑몰삼성카드 쇼핑 반려생활관 강아지대통령 고양이대통령 어바웃펫 베이컨박스 하림펫푸드 놀로 스토어 3 할인기준 할인기준 전월 이용금액대별 통합 월 할인한도의 정보 제공 40만원 이상 80만원 이상 120만원 이상 n10000원n30000원n50000원n 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~80만원 미만 실적구간 혜택 제공전월 이용금액 80만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 온라인 간편결제 5% 결제일할인 2 대상점 업종할인 대상 온라인 간편결제삼성페이 네이버페이 카카오페이 PAYCO 스마일페이 coupay SSGPAY L.PAY 3 할인기준 할인기준 전월 이용금액대별 통합 월 할인한도의 정보 제공 40만원 이상 80만원 이상 120만원 이상 n3000원n6000원n10000원n 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~80만원 미만 실적구간 혜택 제공전월 이용금액 80만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 손해보험 10% 결제일할인 2 대상점 업종할인 대상 손해보험펫보험 자동차보험 화재보험 운전자보험 상해보험 등 모든 손해보험 3 할인기준 할인기준 전월 이용금액대별 통합 월 할인한도의 정보 제공 40만원 이상 80만원 이상 120만원 이상 n3000원n6000원n10000원n 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~80만원 미만 실적구간 혜택 제공전월 이용금액 80만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 해외 1.5% 결제일할인 2 대상점 업종할인 대상 해외해외 가맹점 및 해외 직접구매 이용건 3 이용조건 통합 월 할인한도 100만원 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 스트리밍 이용료 정기결제 시 10% 결제일할인 2 대상점 업종할인 대상 스트리밍넷플릭스 웨이브 티빙 왓챠 멜론 FLO 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 40만원 이상 시 제공 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 커피전문점편의점 건별 1만원 이상 결제 시 1000원 결제일할인 2 대상점 업종할인 대상 커피전문점스타벅스 이디야커피 투썸플레이스 커피빈 블루보틀편의점CU GS25 세븐일레븐 미니스톱 이마트24 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 40만원 이상 시 제공 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건
# 삼성 iD ALL 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1727.gif
# Card Summary 카드 디자인 소개 많이 쓰는 영역 5% 자동 맞춤 할인 주유이동통신아파트 관리비 2.5% 결제일할인 국내외 가맹점 0.5% 결제일할인
# Card Benefit 1 서비스안내 백화점할인점슈퍼마켓 영역 중 월 이용금액이 가장 큰 1개 영역에 대해 5% 결제일할인국내외 가맹점 0.5% 할인 혜택과 중복 적용 2 대상점 영역할인 대상 백화점신세계롯데현대갤러리아 백화점 AK플라자할인점이마트 이마트 트레이더스 롯데마트 홈플러스 농협 하나로마트슈퍼마켓이마트 에브리데이 GS THE FRESH구. GS수퍼마켓 롯데슈퍼 홈플러스 익스프레스 3 할인기준 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 40만원 이상 70만원 이상 n5000원n10000원n 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~70만원 미만 실적구간 혜택 제공전월 이용금액 70만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 주유이동통신아파트 관리비 2.5% 결제일할인 2 대상점 업종할인 대상 주유주유소 LPG충전소 전기차충전소이동통신SKT KT LG U 알뜰폰 이동통신요금 정기결제건아파트 관리비아파트 관리비 정기결제건 3 할인기준 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 40만원 이상 70만원 이상 n5000원n10000원n 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~70만원 미만 실적구간 혜택 제공전월 이용금액 70만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 할인한도 없이 국내외 가맹점 0.5% 결제일할인 2 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금 국세지방세공과금 초중고등학교 학교납입금 대학 등록금 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 부동산 임대료 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 문자알림서비스 스마트오토서비스 이용금액
# 삼성 iD ALL 카드 (포인트)
# https://static11.samsungcard.com/wcms/home/scard/image/personal/b_AAP1729.png
# Card Summary 카드 디자인 소개 많이 쓰는 영역 5% 자동 맞춤 적립 국내외 가맹점 0.5% 빅포인트 적립 주유이동통신아파트 관리비 2% 빅포인트 추가 적립
# Card Benefit 1 서비스안내 백화점할인점슈퍼마켓 영역 중 월 이용금액이 가장 큰 1개 영역에 대해 5% 빅포인트 적립국내외 가맹점 0.5% 빅포인트 적립 혜택과 중복 적용 2 대상점 영역적립 대상 백화점신세계롯데현대갤러리아 백화점 AK플라자할인점이마트 이마트 트레이더스 롯데마트 홈플러스 농협 하나로마트슈퍼마켓이마트 에브리데이 GS THE FRESH구. GS수퍼마켓 롯데슈퍼 홈플러스 익스프레스 3 적립기준 전월 이용금액대별 월 적립한도40만원 이상70만원 이상 5000P10000P 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~70만원 미만 실적구간 혜택 제공전월 이용금액 70만원 이상 시에는 해당 실적구간 혜택 제공 5 적립 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 적립한도 없이 국내외 가맹점 0.5% 빅포인트 기본 적립 2 적립 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금 국세지방세공과금 초중고등학교 학교납입금 대학 등록금 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 부동산 임대료 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 문자알림서비스 스마트오토서비스 이용금액 1 서비스안내 주유이동통신아파트 관리비 2% 빅포인트 추가 적립 2 대상점 업종적립 대상 주유주유소 LPG충전소 전기차충전소이동통신SKT KT LG U 알뜰폰 이동통신요금 정기결제건아파트 관리비아파트 관리비 정기결제건 3 적립기준 전월 이용금액대별 통합 월 적립한도40만원 이상70만원 이상 5000P10000P 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~70만원 미만 실적구간 혜택 제공전월 이용금액 70만원 이상 시에는 해당 실적구간 혜택 제공 5 적립 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건
# 삼성 iD MOVE 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1762.gif
# Card Summary 카드 디자인 소개 대중교통택시 10% 결제일할인 이동통신스트리밍 10% 결제일할인 커피전문점편의점 10% 결제일할인 해외항공철도 1.5% 결제일할인
# Card Benefit 1 서비스안내 대중교통택시 10% 결제일할인 2 대상점 업종할인 대상 대중교통버스 지하철택시택시 3 전월 이용금액대별 통합 월 할인한도 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 40만원 이상 5000원 80만원 이상 12000원 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~80만원 미만 실적구간 혜택 제공전월 이용금액 80만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 이동통신스트리밍 10% 결제일할인 2 대상점 업종할인 대상 이동통신SKT KT LG U 알뜰폰SK텔링크 KT스카이라이프 KT M모바일 헬로모바일 미디어로그 이동통신요금 정기결제건스트리밍넷플릭스 웨이브 티빙 왓챠 멜론 FLO 정기결제건 3 전월 이용금액대별 통합 월 할인한도 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 40만원 이상 5000원 80만원 이상 12000원 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~80만원 미만 실적구간 혜택 제공전월 이용금액 80만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 커피전문점편의점 10% 결제일할인 2 대상점 업종할인 대상 커피전문점스타벅스 이디야커피 투썸플레이스 커피빈 블루보틀편의점CU GS25 세븐일레븐 미니스톱 이마트24 3 전월 이용금액대별 통합 월 할인한도 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 40만원 이상 3000원 80만원 이상 6000원 4 이용조건 발급월1개월까지는 전월 이용금액 40만원 미만 시에도 40만원 이상~80만원 미만 실적구간 혜택 제공전월 이용금액 80만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 해외항공철도 1.5% 결제일할인 2 대상점 업종할인 대상 해외해외 가맹점 및 해외 직접구매 이용건항공대한한공 아시아나항공 제주항공 티웨이항공 진에어철도철도KTX SRT 포함 3 할인 제외 대상 통합 월 할인한도 50만원
# 삼성 iD CLASSY 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/b_AAP1787.png
# Card Summary 기프트 서비스 국내외 가맹점 0.5~2% 빅포인트 적립 커피전문점 20% 결제일할인 영화 5천원 결제일할인
# Card Benefit
# 삼성 iD NOMAD 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/b_AAP1786.gif
# Card Summary 기프트 서비스 국내외 가맹점 2%1%0.5% 빅포인트적립 디지털콘텐츠멤버십 50% 결제일할인 쉐이크쉑써브웨이 30% 결제일할인 영화 5000원 결제일할인 Mastercard PLATINUM 등급 서비스
# Card Benefit 1 서비스안내 여행여가면세점 영역에서 건별 10만원 이상 결제 시 20000원 결제일할인영역별 연 1회 2 대상점 영역구분할인 대상 여행항공대한항공 아시아나항공 제주항공 진에어 티웨이항공여행여행사여가골프골프장 골프연습장백화점신세계롯데현대갤러리아백화점 AK 플라자 프리미엄 아울렛신세계사이먼 프리미엄 아울렛 현대프리미엄아울렛 롯데프리미엄아울렛온라인패션몰나이키닷컴 SSF SHOP 무신사 와인와인앤모어 공연인터파크 티켓면세점면세점신라면세점 신라인터넷면세점 3 이용한도 및 조건 통합 연 3회 제공연 기준 발급일로부터 12개월 발급 2차년도 이후에는 전년도발급월로부터 12개월 일시불 및 할부 이용금액 100만원 이상 시 제공발급 첫 해는 이용금액에 관계없이 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 적립한도 없이 국내외 가맹점 2%1%0.5% 빅포인트 적립 2 대상점 적립률구분적립 대상 2%해외해외 가맹점 및 해외 직접구매 이용건1%항공대한항공 아시아나항공 제주항공 진에어 티웨이항공여행여행사골프골프장 골프연습장백화점신세계롯데현대갤러리아백화점 AK 플라자프리미엄 아울렛신세계사이먼 프리미엄 아울렛 현대프리미엄아울렛 롯데프리미엄아울렛온라인쇼핑몰쿠팡 티몬 위메프 SSG.COM G마켓 옥션 11번가 인터파크 삼성카드 쇼핑할인점이마트 롯데마트 홈플러스면세점신라면세점 신라인터넷면세점0.5%그 외 가맹점 3 적립 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금 국세지방세공과금 납부건 부동산 임대료 납부건 유치원 납입금 초중고등학교 학교납입금 대학 등록금 납부건 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 납부건 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 문자알림서비스 스마트오토서비스 이용금액 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 디지털콘텐츠멤버십 정기결제 시 50% 결제일할인 2 대상점 구분할인대상 디지털콘텐츠넷플릭스 유튜브 프리미엄 디즈니 웨이브 티빙 왓챠 멜론 FLO멤버십네이버플러스 멤버십 3 이용한도 및 조건 통합 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 쉐이크쉑써브웨이 30% 결제일할인 2 이용한도 및 조건 통합 월 할인한도 10000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 3 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 영화 티켓 건별 12000원 이상 결제 시 5000원 결제일할인 2 대상점 구분할인대상 영화CGV 롯데시네마 메가박스 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건
# 삼성 iD EV 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1747.gif
# Card Summary
# Card Benefit 1 서비스안내 전기차 충전요금 50%70% 결제일할인 2 대상점 구분할인 대상 전기차 충전 사업자환경부한국자동차환경협회파워큐브 한국전력 테슬라 지에스차지비 한국전기차충전서비스xa0SKxa0일렉링크 대영채비 EPit 제주전기자동차서비스 소프트베리 SK에너지 GS칼텍스 에버온 3 할인기준 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 전월 이용금액 30만원 이상 60만원 이상 n할인율n50%n70%n n할인한도 n20000원n30000원n 4 이용조건 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 30만원 이상~60만원 미만 실적구간 혜택 제공전월 이용금액 60만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 주차장하이패스대리운전 10% 결제일 할인 2 대상점 구분할인 대상 주차장케이엠파크하이패스고속도로 통행료대리운전카카오 T 대리 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 30만원 이상 시 제공 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 현대해상 다이렉트 자동차보험 보험료 30만원 이상 결제 시 30000원 결제일할인 2 이용조건 연 1회 제공연 기준 1.1~12.31 3 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 배달앱 10% 결제일할인 2 대상점 업종할인 대상 배달앱배달의민족 쿠팡이츠 3 할인기준 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 30만원 이상 60만원 이상 n5000원n10000원n 4 이용조건 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 30만원 이상~60만원 미만 실적구간 혜택 제공전월 이용금액 60만원 이상 시에는 해당 실적구간 혜택 제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 스트리밍 이용료 정기결제 시 20% 결제일할인 2 대상점 업종할인 대상 스트리밍넷플릭스 웨이브 티빙 왓챠 멜론 FLO 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 30만원 이상 시 제공 발급월1개월까지는 전월 이용금액 30만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니등 전자지급수단 포함 구매 및 충전 상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 할인한도 없이 해외 1% 결제일할인 2 대상점 업종할인 대상 해외해외 가맹점 및 해외 직접구매 이용건 3 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트 사이버머니등 전자지급수단 포함 구매 및 충전 상품권 구매건
# 삼성 iD EDU 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1756.gif
# Card Summary 카드 디자인 소개 교육 10% 결제일할인 아파트 관리비 5천원 결제일할인 온라인쇼핑몰 멤버십 50% 결제일할인 배달앱 5% 결제일할인 해외 1.5% 결제일할인
# Card Benefit
# 삼성 iD AUTO 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1766.gif
# Card Summary 카드 디자인 소개 주유 리터당 70원90원 결제일할인 주차장하이패스대리운전 10% 결제일할인 국내외 가맹점 0.5% 결제일할인 생활필수영역 1.5% 결제일할인 영화 5000원 결제일할인 차량 점검 서비스
# Card Benefit 1 서비스안내 모든 주유소 리터당 70원90원 결제일할인 2 할인기준 전월 이용금액대별 통합 월 할인한도를 확인할 수 있는 표입니다. 50만원 이상 100만원 이상 n70원n90원n 3 이용조건 일 1회 1회당 주유금액 10만원까지 월 주유금액 30만원까지 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 50만원이상~100만원 미만 실적구간 혜택 제공 전월 이용금액 100만원 이상 시에는 해당 실적구간 혜택 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트xa0사이버머니 등 전자지급수단 포함xa0구매 및 충전xa0상품권 구매건 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 주차장하이패스대리운전 10% 결제일할인 2 대상점 구분할인 대상 주차장케이엠파크하이패스고속도로 통행료대리운전카카오 T 대리 3 이용조건 통합 월 할인한도 5000원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트xa0사이버머니 등 전자지급수단 포함xa0구매 및 충전xa0상품권 구매건 1 서비스안내 전월 이용금액에 관계없이 할인한도 없이 국내외 가맹점 0.5% 결제일할인 2 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 건강보험국민연금고용보험산재보험 및 장애인 고용부담금xa0국세지방세공과금 납부건 부동산 임대료 납부건 초중고등학교 학교납입금xa0대학 등록금 납부건 대중교통xa0택시xa0고속버스차내 단말기 및 고속버스 앱 결제xa0삼성xa0iD AUTOxa0카드를 통한 고속도로 통행요금 납부건 기프트선불카드포인트xa0사이버머니 등 전자지급수단 포함xa0구매 및 충전xa0상품권 구매건 문자알림서비스xa0스마트오토서비스 이용금액 삼성카드와 구매캐시백 포인트 제공 계약을 체결한 일부 가맹점 의약품유류 구매한도 대금결제건 1 서비스안내 할인점온라인쇼핑몰편의점배달앱커피전문점 1.5% 결제일할인 2 대상점 업종할인 대상 할인점이마트 이마트 트레이더스 롯데마트 홈플러스온라인쇼핑몰쿠팡 티몬 위메프 SSG.COM G마켓 옥션 11번가 인터파크 삼성카드 쇼핑편의점CU GS25 세븐일레븐 미니스톱 이마트24배달앱배달의민족 요기요커피전문점스타벅스 이디야커피 투썸플레이스 카페베네 탐앤탐스 커피빈 엔제리너스 할리스커피 파스쿠찌 아티제 폴 바셋 블루보틀 3 이용조건 통합 월 할인한도 100만원 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트xa0사이버머니 등 전자지급수단 포함xa0구매 및 충전xa0상품권 구매건 1 서비스안내 영화 티켓 12000원 이상 결제 시 5000원 결제일할인 2 대상점 업종할인 대상 영화CGV 롯데시네마 메가박스 3 이용조건 통합 월 1회 제공 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트xa0사이버머니 등 전자지급수단 포함xa0구매 및 충전xa0상품권 구매건 1 서비스안내 엔진오일오일필터에어클리너 포함 교환 시 20000원 현장할인월 1회 연 2회차량 안전점검 무료연 1회타이어 펑크 수리 무료연 1회 1개 기준타이어 위치 교환 무료연 1회 휠밸런스 2개 포함 2 대상점 업종할인 대상 차량정비스피드메이트 3 이용조건 연 기준 1.1~12.31 전월 이용금액 50만원 이상 시 제공 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 제공 4 할인 제외 대상 무이자할부 이용금액 삼성카드 할인이 적용된 일시불 및 할부 이용금액 기프트선불카드포인트xa0사이버머니 등 전자지급수단 포함xa0구매 및 충전xa0상품권 구매건
# 삼성 BIZ iD BENEFIT 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/DN_AAP1758.gif
# Card Summary
# Card Benefit 1 서비스안내 전월 이용금액에 관계없이 4대 사회보험도시가스요금전기요금할인점온라인쇼핑몰식자재몰해외 1.5% 결제일할인 2 대상점 구분할인 대상 4대 사회보험건강보험 국민연금 고용보험 산재보험도시가스요금도시가스요금전기요금주택용 전력 주거용 심야전력 계약전력 20kW 이하일반용 교육용 산업용 농업용할인점이마트 이마트 트레이더스 롯데마트 홈플러스온라인쇼핑몰쿠팡 티몬 위메프 G마켓 옥션 11번가인터파크 삼성카드 쇼핑식자재몰배민상회해외해외 가맹점 및 해외 직접구매 이용건 3 이용조건 통합 월 할인한도 30만원 4 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 국세지방세공과금 장애인 고용부담금 초중고등학교 학교납입금 대학 등록금 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 부동산 임대료 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 문자알림서비스 스마트오토서비스 이용금액공과금 중 4대 사회보험 도시가스요금 전기요금은 할인 적용 공과금 중 4대 사회보험 도시가스요금 전기요금은 할인 적용 1 서비스안내 전월 이용금액에 관계없이 할인한도 없이 국내 가맹점 0.5% 결제일할인 2 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 국세지방세공과금 장애인 고용부담금 초중고등학교 학교납입금 대학 등록금 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 부동산 임대료 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 문자알림서비스 스마트오토서비스 이용금액공과금 중 4대 사회보험 도시가스요금 전기요금은 할인 적용 공과금 중 4대 사회보험 도시가스요금 전기요금은 할인 적용 1 서비스안내 주유전기차 충전요금이동통신인터넷유선통신렌탈보안방역 3% 결제일할인 2 대상점 구분할인 대상 주유모든 주유소 및 LPG충전소전기차 충전사업자환경부한국자동차환경협회 파워큐브 한국전력 테슬라 한국전기차충전서비스 SK 일렉링크 대영채비 EPit 제주전기자동차서비스 소프트베리 SK에너지 GS칼텍스 에버온 지에스차지비이동통신SKT KT LG U 알뜰폰SK텔링크 KT스카이라이프 KT M모바일 헬로모바일 미디어로그 이동통신요금 정기결제건인터넷유선통신SK브로드밴드 KT LG U 인터넷유선전화요금정기결제건렌탈코웨이 SK매직 웰스 정기결제건보안에스원 정기결제건방역세스코 정기결제건 3 할인기준 전월 이용금액대별 월 할인기준을 확인할 수 있는 표입니다. 50만원 이상 100만원 이상 n10000원n20000원n 4 이용조건 발급월1개월까지는 전월 이용금액 50만원 미만 시에도 50만원 이상~100만원 미만 실적구간혜택제공 전월 이용금액 100만원 이상 시에는 해당 실적구간 혜택제공 5 할인 제외 대상 무이자할부 삼성카드 할인이 적용된 일시불 및 할부 이용금액 국세지방세공과금 장애인 고용부담금 초중고등학교 학교납입금 대학 등록금 대중교통 택시 고속버스차내 단말기 및 고속버스 앱 결제 고속도로 통행요금 부동산 임대료 기프트선불카드포인트 사이버머니 등 전자지급수단 포함 구매 및 충전 상품권 구매 문자알림서비스 스마트오토서비스 이용금액공과금 중 4대 사회보험 도시가스요금 전기요금은 할인 적용 공과금 중 4대 사회보험 도시가스요금 전기요금은 할인 적용 1 서비스안내 부가세환급 편의지원서비스 및 전자세금계산서 월 250건 무료 2 부가세환급 편의지원서비스 신용카드 이용내역을 부가세 환급 대상비대상으로 자동 분류하여 부가세 신고 기초자료로 제공
# 삼성 iD POCKET 카드
# https://static11.samsungcard.com/wcms/home/scard/image/personal/b_AAP1746.gif
# Card Summary 만 12세~18세 청소년 전용 가족카드이며 해당 카드는 홈페이지앱을 통해서만 신청이 가능합니다. 카드 디자인 소개 대중교통 1%2% 결제일할인 편의점배달앱델리커피전문점 1%8% 결제일할인
# Card Benefit
